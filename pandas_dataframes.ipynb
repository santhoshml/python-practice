# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshml/python-practice/blob/main/pandas_dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from numpy.random import seed

# %%
my_data = randn(4,3)
my_rows = ['A','B','C','D']
my_columns = ['Monday','Tuesday','Wednesday']

# %%
my_df = pd.DataFrame(my_data, my_rows, my_columns)
my_df
# Out:
#      Monday   Tuesday  Wednesday
# A -1.324271  0.600524   0.690650
# B  0.615814  1.326661   0.061708
# C  0.466795  0.042175   0.810951
# D -2.178465 -0.754160   0.150710

# %%
my_df2=pd.read_csv('./sample_data/california_housing_test.csv')
my_df2
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
my_df2.loc[0]
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %%
my_df2.loc[[0, 5, 8]]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 8    -122.84     38.40                15.0       3080.0           617.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 5       663.0       204.0         1.6635             67000.0
# 8      1446.0       599.0         3.6696            194400.0

# %%
my_df2.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
my_df2.head(9)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# ...

# %%
my_df2.tail(5)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
my_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
my_df2.shape
# Out:
# (3000, 9)

# %%
my_df2.ndim
# Out:
# 2

# %%
my_df2.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
my_df2.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
my_df2['longitude'].describe()
# Out:
# count    3000.000000
# mean     -119.589200
# std         1.994936
# min      -124.180000
# 25%      -121.810000
# 50%      -118.485000
# 75%      -118.020000
# max      -114.490000
# Name: longitude, dtype: float64

# %%
my_df2['longitude']
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
my_df2.longitude
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
my_df2.iloc[1: 5, 1: 5]
# Out:
#    latitude  housing_median_age  total_rooms  total_bedrooms
# 1     34.26                43.0       1510.0           310.0
# 2     33.78                27.0       3589.0           507.0
# 3     33.82                28.0         67.0            15.0
# 4     36.33                19.0       1241.0           244.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['latitude'].plot(kind='hist', bins=20, title='latitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['housing_median_age'].plot(kind='hist', bins=20, title='housing_median_age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['total_rooms'].plot(kind='hist', bins=20, title='total_rooms')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
# my_df2['total_rooms'].value_counts()
my_df2['total_rooms'].value_counts(ascending=True)
# Out:
# total_rooms
# 4721.0    1
# 4044.0    1
# 4164.0    1
# 725.0     1
# 844.0     1
#          ..
# 956.0     4
# 1778.0    5
# 1966.0    5
# 1787.0    5
# 907.0     5
# Name: count, Length: 2215, dtype: int64

# %%
my_df2['total_rooms'].value_counts(normalize=True)
# Out:
# total_rooms
# 907.0     0.001667
# 1787.0    0.001667
# 1778.0    0.001667
# 1966.0    0.001667
# 1499.0    0.001333
#             ...
# 1132.0    0.000333
# 3199.0    0.000333
# 1433.0    0.000333
# 4602.0    0.000333
# 5257.0    0.000333
# Name: proportion, Length: 2215, dtype: float64

# %%
my_df2['total_rooms'].value_counts()[907]
# Out:
# 5

# %%
my_df2.groupby('total_rooms').count()
# Out:
#              longitude  latitude  housing_median_age  total_bedrooms  \
# total_rooms
# 6.0                  1         1                   1               1
# 16.0                 1         1                   1               1
# 18.0                 1         1                   1               1
# 19.0                 1         1                   1               1
# 21.0                 1         1                   1               1
# ...                ...       ...                 ...             ...
# 21988.0              1         1                   1               1
# 23915.0              1         1                   1               1
# 24121.0              1         1                   1               1
# 27870.0              1         1                   1               1
# 30450.0              1         1                   1               1
#
#              population  households  median_income  median_house_value
# total_rooms
# ...

# %%
my_df2.groupby('total_rooms').size()
# Out:
# total_rooms
# 6.0        1
# 16.0       1
# 18.0       1
# 19.0       1
# 21.0       1
#           ..
# 21988.0    1
# 23915.0    1
# 24121.0    1
# 27870.0    1
# 30450.0    1
# Length: 2215, dtype: int64

# %%
my_df
# Out:
#      Monday   Tuesday  Wednesday
# A -1.324271  0.600524   0.690650
# B  0.615814  1.326661   0.061708
# C  0.466795  0.042175   0.810951
# D -2.178465 -0.754160   0.150710

# %%
my_df['total'] = my_df['Monday'] + my_df['Tuesday'] + my_df['Wednesday']
my_df
# Out:
#      Monday   Tuesday  Wednesday     total
# A -1.324271  0.600524   0.690650 -0.033097
# B  0.615814  1.326661   0.061708  2.004183
# C  0.466795  0.042175   0.810951  1.319921
# D -2.178465 -0.754160   0.150710 -2.781914

# %%
my_df.insert(1, 'is_holiday', [False]*len(my_df))

# %%
my_df
# Out:
#      Monday  is_holiday   Tuesday  Wednesday     total
# A -1.324271       False  0.600524   0.690650 -0.033097
# B  0.615814       False  1.326661   0.061708  2.004183
# C  0.466795       False  0.042175   0.810951  1.319921
# D -2.178465       False -0.754160   0.150710 -2.781914

# %%
my_df3=my_df.assign(is_working=[True]*len(my_df))
my_df3
# Out:
#      Monday  is_holiday   Tuesday  Wednesday     total  is_working
# A -1.324271       False  0.600524   0.690650 -0.033097        True
# B  0.615814       False  1.326661   0.061708  2.004183        True
# C  0.466795       False  0.042175   0.810951  1.319921        True
# D -2.178465       False -0.754160   0.150710 -2.781914        True

# %%
my_df
# Out:
#      Monday  is_holiday   Tuesday  Wednesday     total
# A -1.324271       False  0.600524   0.690650 -0.033097
# B  0.615814       False  1.326661   0.061708  2.004183
# C  0.466795       False  0.042175   0.810951  1.319921
# D -2.178465       False -0.754160   0.150710 -2.781914

# %%
my_df3.drop('is_holiday', axis=1) #inplace=True, if u want to delete forever
# Out:
#      Monday   Tuesday  Wednesday     total  is_working
# A -1.324271  0.600524   0.690650 -0.033097        True
# B  0.615814  1.326661   0.061708  2.004183        True
# C  0.466795  0.042175   0.810951  1.319921        True
# D -2.178465 -0.754160   0.150710 -2.781914        True

# %%
my_df3
# Out:
#      Monday  is_holiday   Tuesday  Wednesday     total  is_working
# A -1.324271       False  0.600524   0.690650 -0.033097        True
# B  0.615814       False  1.326661   0.061708  2.004183        True
# C  0.466795       False  0.042175   0.810951  1.319921        True
# D -2.178465       False -0.754160   0.150710 -2.781914        True

# %%
my_df3.loc["A", "Monday"]
# Out:
# -1.3242705343149082

# %%
my_df3.loc[["A", "D"], ["is_working", "Monday", "Wednesday"]]
# Out:
#    is_working    Monday  Wednesday
# A        True -1.324271    0.69065
# D        True -2.178465    0.15071
