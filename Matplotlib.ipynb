# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshml/python-practice/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn

# %%
my_df = pd.DataFrame(randn(100,4), columns=['Mon','Tues','Wed','Thur'])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -0.247120 -0.758388  0.542858  1.272823
# 1  -1.710849 -2.058546  1.143121 -1.678136
# 2  -2.123513 -1.722618 -0.522891 -0.139349
# 3  -0.606751  1.030856 -0.047350  0.899072
# 4   0.396575  0.068931  0.687505  1.633295
# ..       ...       ...       ...       ...
# 95 -0.224679 -1.561066  0.091230 -0.166827
# 96  1.016846 -1.213901  0.294680  0.419584
# 97 -0.171827  1.504757  0.583101  0.171744
# 98  0.558925  0.289373  1.416538  0.223991
# 99 -0.444473 -1.879376 -1.320273  0.177653
#
# [100 rows x 4 columns]

# %%
my_df["Mon"].hist()
# Out:
# <Axes: >

# %%
my_df["Mon"].hist(bins=100)
# Out:
# <Axes: >

# %%
my_df["Mon"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df["Mon"].hist(bins=20, grid=False, legend=True)
# Out:
# <Axes: >

# %%
my_df.plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %%
my_df.abs().plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %%
my_df.abs().plot(kind='area', alpha=0.4)
# Out:
# <Axes: >

# %%
my_df.abs().plot(kind='area', alpha=0.4, title='My Title', legend=False)
# Out:
# <Axes: title={'center': 'My Title'}>

# %%
my_df['Mon'].abs().plot(kind='area', alpha=0.4, title='My Title', legend=False)
# Out:
# <Axes: title={'center': 'My Title'}>

# %%
my_df[['Mon', 'Tues']].abs().plot(kind='area', alpha=0.4, title='My Title', legend=False)
# Out:
# <Axes: title={'center': 'My Title'}>

# %%
my_df.abs().plot(kind='area', alpha=0.4, title='My Title', legend=False, table=True)
# Out:
# <Axes: title={'center': 'My Title'}>

# %%
my_df.plot(kind='bar')
# Out:
# <Axes: >

# %%
my_df.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
my_df.plot(kind='bar', alpha=0.1)
# Out:
# <Axes: >

# %%
my_df.plot(kind='bar', alpha=0.3, title='My Title')
# Out:
# <Axes: title={'center': 'My Title'}>

# %%
my_df.abs().plot(kind='line', lw=5)
# Out:
# <Axes: >

# %%
my_df['Mon'].abs().plot(kind='line', lw=5)
# Out:
# <Axes: >

# %%
my_df[['Mon', 'Wed']].abs().plot(kind='line', lw=0.5, figsize=(10,5))
# Out:
# <Axes: >

# %%
my_df.plot(kind='scatter', x='Mon', y='Tues', c='Wed', cmap='coolwarm')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>
